# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
movies=pd.read_csv("Movie+Assignment+Data.csv")

# %%
movies.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# ...

# %%
movies.shape
# Out:
# (100, 62)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
movies.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %%
movies["Gross"]=movies["Gross"]/1000000
movies["budget"]=movies["budget"]/1000000

# %%
movies
# Out:
#                                            Title  title_year  budget  \
# 0                                     La La Land        2016    30.0
# 1                                       Zootopia        2016   150.0
# 2                                           Lion        2016    12.0
# 3                                        Arrival        2016    47.0
# 4                          Manchester by the Sea        2016     9.0
# ..                                           ...         ...     ...
# 95                                      Whiplash        2014     3.3
# 96                               Before Midnight        2013     3.0
# 97    Star Wars: Episode VII - The Force Awakens        2015   245.0
# 98  Harry Potter and the Deathly Hallows: Part I        2010   150.0
# 99                       Tucker and Dale vs Evil        2010     5.0
#
#         Gross              actor_1_name        actor_2_name  \
# 0   151101803              Ryan Gosling          Emma Stone
# ...

# %%
# Create the new column named 'profit' by subtracting the 'budget' column from the 'gross' column

# %%
movies["profit"]=movies["Gross"]-movies["budget"]

# %%
movies
# Out:
#                                          Title  title_year  budget      Gross  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0  936662225
# 11                                The Avengers        2012   220.0  623279547
# 8                        The Dark Knight Rises        2012   250.0  448130642
# 32             The Hunger Games: Catching Fire        2013   130.0  424645577
# 12                                 Toy Story 3        2010   200.0  414984497
# ..                                         ...         ...     ...        ...
# 96                             Before Midnight        2013     3.0    8114507
# 82                                     Flipped        2010    14.0    1752214
# 39                           The Little Prince        2015    81.2    1339152
# 89                                       Amour        2012     8.9     225377
# 99                     Tucker and Dale vs Evil        2010     5.0     223838
#
# ...

# %%
# Sort the dataframe with the 'profit' column as reference using the 'sort_values' function. Make sure to set the argument

# %%
movies=movies.sort_values("profit",ascending=False)

# %%
movies
# Out:
#                                          Title  title_year  budget      Gross  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0  936662225
# 11                                The Avengers        2012   220.0  623279547
# 8                        The Dark Knight Rises        2012   250.0  448130642
# 32             The Hunger Games: Catching Fire        2013   130.0  424645577
# 12                                 Toy Story 3        2010   200.0  414984497
# ..                                         ...         ...     ...        ...
# 96                             Before Midnight        2013     3.0    8114507
# 82                                     Flipped        2010    14.0    1752214
# 39                           The Little Prince        2015    81.2    1339152
# 89                                       Amour        2012     8.9     225377
# 99                     Tucker and Dale vs Evil        2010     5.0     223838
#
# ...

# %%
#Get the top 10 profitable movies by using position based indexing. Specify the rows till 10 (0-9)

# %%
movies.iloc[:10,:]
# Out:
#                                          Title  title_year  budget      Gross  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0  936662225
# 11                                The Avengers        2012   220.0  623279547
# 8                        The Dark Knight Rises        2012   250.0  448130642
# 32             The Hunger Games: Catching Fire        2013   130.0  424645577
# 12                                 Toy Story 3        2010   200.0  414984497
# 9                   Captain America: Civil War        2016   250.0  407197282
# 47                                    Deadpool        2016    58.0  363024263
# 18                                  Inside Out        2015   175.0  356454367
# 1                                     Zootopia        2016   150.0  341268248
# 19                     Guardians of the Galaxy        2014   170.0  333130696
#
#          actor_1_name        actor_2_name           actor_3_name  \
# ...

# %%
#Plot profit vs budget

# %%
import seaborn as sns

# %%
sns.jointplot("budget","Profit",data=movies)

# %%
#Find the movies with negative profit

# %%
movies
# Out:
#                                          Title  title_year  budget      Gross  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0  936662225
# 11                                The Avengers        2012   220.0  623279547
# 8                        The Dark Knight Rises        2012   250.0  448130642
# 32             The Hunger Games: Catching Fire        2013   130.0  424645577
# 12                                 Toy Story 3        2010   200.0  414984497
# ..                                         ...         ...     ...        ...
# 96                             Before Midnight        2013     3.0    8114507
# 82                                     Flipped        2010    14.0    1752214
# 39                           The Little Prince        2015    81.2    1339152
# 89                                       Amour        2012     8.9     225377
# 99                     Tucker and Dale vs Evil        2010     5.0     223838
#
# ...

# %%
movies[movies["profit"]<0]
# Out:
# Empty DataFrame
# Columns: [Title, title_year, budget, Gross, actor_1_name, actor_2_name, actor_3_name, actor_1_facebook_likes, actor_2_facebook_likes, actor_3_facebook_likes, IMDb_rating, genre_1, genre_2, genre_3, MetaCritic, Runtime, CVotes10, CVotes09, CVotes08, CVotes07, CVotes06, CVotes05, CVotes04, CVotes03, CVotes02, CVotes01, CVotesMale, CVotesFemale, CVotesU18, CVotesU18M, CVotesU18F, CVotes1829, CVotes1829M, CVotes1829F, CVotes3044, CVotes3044M, CVotes3044F, CVotes45A, CVotes45AM, CVotes45AF, CVotes1000, CVotesUS, CVotesnUS, VotesM, VotesF, VotesU18, VotesU18M, VotesU18F, Votes1829, Votes1829M, Votes1829F, Votes3044, Votes3044M, Votes3044F, Votes45A, Votes45AM, Votes45AF, Votes1000, VotesUS, VotesnUS, content_rating, Country, gross, Profit, profit]
# Index: []
#
# [0 rows x 65 columns]

# %%
# Change the scale of MetaCritic

# %%
import pandas as pd

# %%
movies=pd.read_csv("Movie+Assignment+Data.csv")

# %%
movies["MetaCritic"]=movies["MetaCritic"]/10

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Write your code here

# %%
movies=pd.read_csv("Movie+Assignment+Data.csv")

# %%
group=movies.pivot_table(index=["actor_1_facebook_likes","actor_2_facebook_likes","actor_3_facebook_likes"],values=["actor_1_name","actor_2_name","actor_3_name"],
     
                        aggfunc="sum")
group
# Out:
#                                                                                   actor_1_name  \
# actor_1_facebook_likes actor_2_facebook_likes actor_3_facebook_likes
# 39                     23.0                   13.0                              Phaldut Sharma
# 131                    12.0                   0.0                                  Doug Walker
# 140                    63.0                   48.0                    Seamus Davey-Fitzpatrick
# 149                    145.0                  123.0                              Elina Alminas
# 230                    193.0                  127.0                             Ellar Coltrane
# ...                                                                                        ...
# 33000                  96000.0                9800.0                                 Dev Patel
# 34000                  13000.0                1000.0                         Jennifer Lawrence
# ...

# %%
group["total likes"]=group["actor_1_name"]+group["actor_2_name"]+group["actor_3_name"]

# %%
group
# Out:
#                                                                                   actor_1_name  \
# actor_1_facebook_likes actor_2_facebook_likes actor_3_facebook_likes
# 39                     23.0                   13.0                              Phaldut Sharma
# 131                    12.0                   0.0                                  Doug Walker
# 140                    63.0                   48.0                    Seamus Davey-Fitzpatrick
# 149                    145.0                  123.0                              Elina Alminas
# 230                    193.0                  127.0                             Ellar Coltrane
# ...                                                                                        ...
# 33000                  96000.0                9800.0                                 Dev Patel
# 34000                  13000.0                1000.0                         Jennifer Lawrence
# ...

# %%
group.sort_values(["actor_1_name","actor_1_name","actor_1_name"])
# Out:
#                                                                                   actor_1_name  \
# actor_1_facebook_likes actor_2_facebook_likes actor_3_facebook_likes
# 5000                   972.0                  773.0                   Aidan TurnerAidan Turner
# 883                    563.0                  393.0                              Albert Finney
# 559                    427.0                  303.0                                Aldis Hodge
# 1000                   767.0                  384.0                                Amy Poehler
# 10000                  349.0                  81.0                             Andrew Garfield
# ...                                                                                        ...
# 15000                  1000.0                 721.0                                  Tom Hanks
# 27000                  798.0                  581.0                                  Tom Hardy
# ...

# %%
group=movies.pivot_table(values=["actor_1_facebook_likes","actor_2_facebook_likes","actor_3_facebook_likes"],index=["actor_1_name","actor_2_name","actor_3_name"],
     
                        aggfunc="sum")
group
# Out:
#                                                     actor_1_facebook_likes  \
# actor_1_name  actor_2_name    actor_3_name
# Aidan Turner  Adam Brown      James Nesbitt                          10000
# Albert Finney Helen McCrory   Rory Kinnear                             883
# Aldis Hodge   Neil Brown Jr.  R. Marcos Taylor                         559
# Amy Adams     Jeremy Renner   Forest Whitaker                        35000
# Amy Poehler   Mindy Kaling    Phyllis Smith                           1000
# ...                                                                    ...
# Tom Hanks     Mark Rylance    Amy Ryan                               15000
# Tom Hardy     Charlize Theron ZoÃ« Kravitz                           27000
#               Christian Bale  Joseph Gordon-Levitt                   27000
#               Frank Grillo    Kevin Dunn                             27000
# Tom Hughes    Tom Hollander   Lindsay Duncan                           565
#
# ...

# %%
group.sort_values(["actor_1_facebook_likes","actor_2_facebook_likes","actor_3_facebook_likes"],ascending=False,inplace=True)

# %%
group
# Out:
#                                                                     actor_1_facebook_likes  \
# actor_1_name             actor_2_name       actor_3_name
# Amy Adams                Jeremy Renner      Forest Whitaker                          35000
# Jennifer Lawrence        Peter Dinklage     Hugh Jackman                             34000
#                          Robert De Niro     Bradley Cooper                           34000
#                          Josh Hutcherson    Sandra Ellis Lafferty                    34000
#                          Michael Fassbender Oliver Platt                             34000
# ...                                                                                    ...
# Ellar Coltrane           Lorelei Linklater  Libby Villari                              230
# Elina Alminas            Sonoya Mizuno      Corey Johnson                              149
# Seamus Davey-Fitzpatrick Ariane Labed       Athina Rachel Tsangari                     140
# ...

# %%
group.reset_index(inplace=True)

# %%
group
# Out:
#     index              actor_1_name        actor_2_name  \
# 0       0                 Amy Adams       Jeremy Renner
# 1       1         Jennifer Lawrence      Peter Dinklage
# 2       2         Jennifer Lawrence      Robert De Niro
# 3       3         Jennifer Lawrence     Josh Hutcherson
# 4       4         Jennifer Lawrence  Michael Fassbender
# ..    ...                       ...                 ...
# 94     94            Ellar Coltrane   Lorelei Linklater
# 95     95             Elina Alminas       Sonoya Mizuno
# 96     96  Seamus Davey-Fitzpatrick        Ariane Labed
# 97     97               Doug Walker          Rob Walker
# 98     98            Phaldut Sharma       Basher Savage
#
#               actor_3_name  actor_1_facebook_likes  actor_2_facebook_likes  \
# 0          Forest Whitaker                   35000                  5300.0
# 1             Hugh Jackman                   34000                 22000.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
movies=pd.read_csv("Movie+Assignment+Data.csv")

# %%
movies.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# ...

# %%
Subtask 2.5: Find the Most Popular Trios - II

# %%
group=movies.pivot_table(index=["actor_1_facebook_likes","actor_2_facebook_likes","actor_3_facebook_likes"],values=["actor_1_name","actor_2_name","actor_3_name"],
     
                        aggfunc="sum")
group
# Out:
#                                                                                   actor_1_name  \
# actor_1_facebook_likes actor_2_facebook_likes actor_3_facebook_likes
# 39                     23.0                   13.0                              Phaldut Sharma
# 131                    12.0                   0.0                                  Doug Walker
# 140                    63.0                   48.0                    Seamus Davey-Fitzpatrick
# 149                    145.0                  123.0                              Elina Alminas
# 230                    193.0                  127.0                             Ellar Coltrane
# ...                                                                                        ...
# 33000                  96000.0                9800.0                                 Dev Patel
# 34000                  13000.0                1000.0                         Jennifer Lawrence
# ...

# %%
group.sort_values(["actor_1_name","actor_1_name","actor_1_name"])
# Out:
#                                                                                   actor_1_name  \
# actor_1_facebook_likes actor_2_facebook_likes actor_3_facebook_likes
# 5000                   972.0                  773.0                   Aidan TurnerAidan Turner
# 883                    563.0                  393.0                              Albert Finney
# 559                    427.0                  303.0                                Aldis Hodge
# 1000                   767.0                  384.0                                Amy Poehler
# 10000                  349.0                  81.0                             Andrew Garfield
# ...                                                                                        ...
# 15000                  1000.0                 721.0                                  Tom Hanks
# 27000                  798.0                  581.0                                  Tom Hardy
# ...

# %%
group["total likes"]=group["actor_1_name"]+group["actor_2_name"]+group["actor_3_name"]

# %%
group
# Out:
#                                                                                   actor_1_name  \
# actor_1_facebook_likes actor_2_facebook_likes actor_3_facebook_likes
# 39                     23.0                   13.0                              Phaldut Sharma
# 131                    12.0                   0.0                                  Doug Walker
# 140                    63.0                   48.0                    Seamus Davey-Fitzpatrick
# 149                    145.0                  123.0                              Elina Alminas
# 230                    193.0                  127.0                             Ellar Coltrane
# ...                                                                                        ...
# 33000                  96000.0                9800.0                                 Dev Patel
# 34000                  13000.0                1000.0                         Jennifer Lawrence
# ...

# %%
j=0
for i in group["total likes"]:
    temp=sorted([group.loc[j,"actor_1_facebook_likes"],group.loc[j,"actor_2_facebook_likes"],group.loc[j,"actor_3_facebook_likes"]])
    if temp[0]>= temp[1]/2 and temp[0]>=temp[2]/2 and temp[1]>=temp[2]/2:
        print(sorted([group.loc[j,"actor_1_name"],group.loc[j,"actor_2_name"],group.loc[j,"actor_3_name"]]))

    j=j+1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-6075bebecea6> in <module>
#       1 j=0
#       2 for i in group["total likes"]:
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
movies=pd.read_csv("Movie+Assignment+Data.csv")

# %%
movies.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# ...

# %%
movies.columns
# Out:
# Index(['Title', 'title_year', 'budget', 'Gross', 'actor_1_name',
#        'actor_2_name', 'actor_3_name', 'actor_1_facebook_likes',
#        'actor_2_facebook_likes', 'actor_3_facebook_likes', 'IMDb_rating',
#        'genre_1', 'genre_2', 'genre_3', 'MetaCritic', 'Runtime', 'CVotes10',
#        'CVotes09', 'CVotes08', 'CVotes07', 'CVotes06', 'CVotes05', 'CVotes04',
#        'CVotes03', 'CVotes02', 'CVotes01', 'CVotesMale', 'CVotesFemale',
#        'CVotesU18', 'CVotesU18M', 'CVotesU18F', 'CVotes1829', 'CVotes1829M',
#        'CVotes1829F', 'CVotes3044', 'CVotes3044M', 'CVotes3044F', 'CVotes45A',
#        'CVotes45AM', 'CVotes45AF', 'CVotes1000', 'CVotesUS', 'CVotesnUS',
#        'VotesM', 'VotesF', 'VotesU18', 'VotesU18M', 'VotesU18F', 'Votes1829',
#        'Votes1829M', 'Votes1829F', 'Votes3044', 'Votes3044M', 'Votes3044F',
#        'Votes45A', 'Votes45AM', 'Votes45AF', 'Votes1000', 'VotesUS',
#        'VotesnUS', 'content_rating', 'Country'],
#       dtype='object')

# %%
plt.hist(movies["Runtime"])
plt.show()

# %%
Subtask 2.7: R-Rated Movies

# %%
Although R rated movies are restricted movies for the under 18 age group, still there are vote counts from that age group. 
Among all the R rated movies that have been voted by the under-18 age group, find the top 10 movies that have the highest
number of votes i.e.CVotesU18 from the movies dataframe. Store these in a dataframe named PopularR.

# %%
movies.loc[movies["content_rating"]=="R"].sort_values("CVotesU18",ascending=False)[["Title","CVotesU18"]].head(10)
# Out:
#                                               Title  CVotesU18
# 47                                         Deadpool       4598
# 36                          The Wolf of Wall Street       3622
# 35                                 Django Unchained       3250
# 29                               Mad Max: Fury Road       3159
# 95                                         Whiplash       2878
# 31                                     The Revenant       2619
# 40                                   Shutter Island       2321
# 43                                        Gone Girl       2286
# 65                         The Grand Budapest Hotel       2083
# 72  Birdman or (The Unexpected Virtue of Ignorance)       1891

# %%
First create a new dataframe df_by_genre that contains genre_1, genre_2, and genre_3 and all
the columns related to CVotes/Votes from the movies data frame. 
There are 47 columns to be extracted in total.

# %%
df_by_genre=movies.loc[:,"CVotes10":"VotesnUS"]
df_by_genre[["genre_1","genre_2","genre_3"]]=movies[["genre_1","genre_2","genre_3"]]

# %%
df_by_genre
# Out:
#     CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  CVotes04  \
# 0      74245     71191     64640     38831     17377      8044      3998
# 1      53626     70912    102352     57261     16719      4539      1467
# 2      23325     29830     40564     20296      5842      1669       558
# 3      55533     87850    109536     65440     26913     10556      5057
# 4      18191     33532     46596     29626     11879      4539      1976
# ..       ...       ...       ...       ...       ...       ...       ...
# 95    110404    161864    132656     56007     16577      6031      2937
# 96     16953     22109     31439     19251      8142      3412      1649
# 97    155391    161810    166378     99402     40734     18060      8751
# 98     68937     54947    102488     80465     31205     11792      4808
# 99     16572     19818     44460     35863     13456      4588      1684
#
#     CVotes03  CVotes02  CVotes01  ...  Votes3044F  Votes45A  Votes45AM  \
# ...

# %%
# Create a column cnt and initialize it to 1

# %%
df_by_genre["cnt"]=1

# %%
df_by_genre
# Out:
#     CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  CVotes04  \
# 0      74245     71191     64640     38831     17377      8044      3998
# 1      53626     70912    102352     57261     16719      4539      1467
# 2      23325     29830     40564     20296      5842      1669       558
# 3      55533     87850    109536     65440     26913     10556      5057
# 4      18191     33532     46596     29626     11879      4539      1976
# ..       ...       ...       ...       ...       ...       ...       ...
# 95    110404    161864    132656     56007     16577      6031      2937
# 96     16953     22109     31439     19251      8142      3412      1649
# 97    155391    161810    166378     99402     40734     18060      8751
# 98     68937     54947    102488     80465     31205     11792      4808
# 99     16572     19818     44460     35863     13456      4588      1684
#
#     CVotes03  CVotes02  CVotes01  ...  Votes45A  Votes45AM  Votes45AF  \
# ...

# %%
# Group the movies by individual genres

# %%
df_by_g1=df_by_genre.groupby("genre_1").agg(sum)
df_by_g2=df_by_genre.groupby("genre_2").agg(sum)
df_by_g3=df_by_genre.groupby("genre_3").agg(sum)

# %%
df_by_g1
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_1
# Action      2928407   3261919   4247693   2662020    986774    364234
# Adventure   1058779   1179818   1560541    966275    365486    136985
# Animation    681562    798227   1153214    722782    251076     83069
# Biography    666831   1088430   1654704    962977    306247    100005
# Comedy       371217    496905    770395    518566    205434     81933
# Crime        383290    690221   1083469    627593    206756     71460
# Drama       1080725   1494053   1827363   1078966    417205    163874
# Mystery      150405    230844    278844    132349     45167     15615
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# genre_1                                            ...
# Action       156150     89483     61975    162426  ...      209.1       208.8
# Adventure     58559     33174     22018     48100  ...       92.7        92.6
# ...

# %%
df_by_g2
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_2
# Action       238060    285510    430062    260106     88580     29250
# Adventure   2297820   2548864   3271725   2055600    758009    272735
# Biography    185172    313178    576374    370003    119348     38643
# Comedy       428995    624720    854162    512668    193916     76752
# Crime         19576     40247     85359     64633     24920      8548
# Drama       1923492   2761237   4112363   2492241    853434    300100
# Family        68937     54947    102488     80465     31205     11792
# Fantasy      270616    290831    447307    291071    120920     47215
# History       15757     32840     83322     63800     19183      5178
# Horror        16572     19818     44460     35863     13456      4588
# Music        110404    161864    132656     56007     16577      6031
# Musical       54268     47750     63323     45160     22393     10744
# ...

# %%
df_by_g3
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_3
# Adventure    238060    285510    430062    260106     88580     29250
# Comedy       583404    653362    882294    559835    200937     68167
# Crime        171660    236650    250667    129164     46715     18682
# Drama        400221    680085   1167327    748493    258717     88338
# Family        29228     40728     77893     62936     27932     11179
# Fantasy      301836    311392    442460    308676    120911     46269
# History      135504    227547    311209    159262     48678     16055
# Music         74245     71191     64640     38831     17377      8044
# Mystery      274446    443661    654167    375087    128131     44818
# Romance      319534    418790    715954    497486    193588     75675
# Sci-Fi      1975041   2169036   2569011   1517219    546668    200825
# Sport         95717    140282    214806    138600     44470     13821
# ...

# %%
# Add the grouped data frames and store it in a new data frame

# %%
df_add=df_by_g1.add(df_by_g2,fill_value=0)
df_add=df_add.add(df_by_g3,fill_value=0)

# %%
df_add
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Family       98165.0    95675.0   180381.0   143401.0    59137.0   22971.0
# Fantasy     572452.0   602223.0   889767.0   599747.0   241831.0   93484.0
# History     151261.0   260387.0   394531.0   223062.0    67861.0   21233.0
# Horror       16572.0    19818.0    44460.0    35863.0    13456.0    4588.0
# ...

# %%
# Extract genres with atleast 10 occurences

# %%
genre_top_10=df_add.loc[df_add["cnt"]>10]

# %%
genre_top_10
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  CVotes05  \
# Action     3166467.0  3547429.0  4677755.0  2922126.0  1075354.0  393484.0
# Adventure  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0  438970.0
# Animation   681562.0   798227.0  1153214.0   722782.0   251076.0   83069.0
# Biography   852003.0  1401608.0  2231078.0  1332980.0   425595.0  138648.0
# Comedy     1383616.0  1774987.0  2506851.0  1591069.0   600287.0  226852.0
# Crime       574526.0   967118.0  1419495.0   821390.0   278391.0   98690.0
# Drama      3404438.0  4935375.0  7107053.0  4319700.0  1529356.0  552312.0
# Romance     549959.0   689492.0  1069280.0   712841.0   281289.0  110901.0
# Sci-Fi     2325284.0  2530855.0  3002994.0  1802098.0   671811.0  254175.0
# Thriller   1081701.0  1465491.0  1993378.0  1175799.0   416046.0  149953.0
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# ...

# %%
# Take the mean for every column by dividing with cnt

# %%
# Rounding off the columns of Votes to two decimals

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
movies=pd.read_csv("Movie+Assignment+Data.csv")

# %%
movies.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# ...

# %%
movies.shape
# Out:
# (100, 62)

# %%
# Check the column-wise info of the dataframe

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
# Check the summary for the numeric columns

# %%
movies.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %%
# Divide the 'gross' and 'budget' columns by 1000000 to convert '$' to 'million $'

# %%
movies["Gross"]=movies["Gross"]/1000000
movies["budget"]=movies["budget"]/1000000

# %%
movies
# Out:
#                                            Title  title_year  budget  \
# 0                                     La La Land        2016    30.0
# 1                                       Zootopia        2016   150.0
# 2                                           Lion        2016    12.0
# 3                                        Arrival        2016    47.0
# 4                          Manchester by the Sea        2016     9.0
# ..                                           ...         ...     ...
# 95                                      Whiplash        2014     3.3
# 96                               Before Midnight        2013     3.0
# 97    Star Wars: Episode VII - The Force Awakens        2015   245.0
# 98  Harry Potter and the Deathly Hallows: Part I        2010   150.0
# 99                       Tucker and Dale vs Evil        2010     5.0
#
#          Gross              actor_1_name        actor_2_name  \
# 0   151.101803              Ryan Gosling          Emma Stone
# ...

# %%
# Create the new column named 'profit' by subtracting the 'budget' column from the 'gross' column

# %%
movies["profit"]=movies["Gross"]-movies["budget"]

# %%
movies
# Out:
#                                            Title  title_year  budget  \
# 0                                     La La Land        2016    30.0
# 1                                       Zootopia        2016   150.0
# 2                                           Lion        2016    12.0
# 3                                        Arrival        2016    47.0
# 4                          Manchester by the Sea        2016     9.0
# ..                                           ...         ...     ...
# 95                                      Whiplash        2014     3.3
# 96                               Before Midnight        2013     3.0
# 97    Star Wars: Episode VII - The Force Awakens        2015   245.0
# 98  Harry Potter and the Deathly Hallows: Part I        2010   150.0
# 99                       Tucker and Dale vs Evil        2010     5.0
#
#          Gross              actor_1_name        actor_2_name  \
# 0   151.101803              Ryan Gosling          Emma Stone
# ...

# %%
# Sort the dataframe with the 'profit' column as reference using the 'sort_values' function. Make sure to set the argument
#'ascending' to 'False'

# %%
movies.sort_values("profit",ascending=False)
# Out:
#                                          Title  title_year  budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015   245.0
# 11                                The Avengers        2012   220.0
# 47                                    Deadpool        2016    58.0
# 32             The Hunger Games: Catching Fire        2013   130.0
# 12                                 Toy Story 3        2010   200.0
# ..                                         ...         ...     ...
# 46                 Scott Pilgrim vs. the World        2010    60.0
# 7                                      Tangled        2010   260.0
# 17                            Edge of Tomorrow        2014   178.0
# 39                           The Little Prince        2015    81.2
# 22                                        Hugo        2011   170.0
#
#          Gross         actor_1_name       actor_2_name           actor_3_name  \
# 97  936.662225          Doug Walker         Rob Walker                      0
# ...

# %%
# Get the top 10 profitable movies by using position based indexing. Specify the rows till 10 (0-9)

# %%
movies.iloc[:10,:]
# Out:
#                         Title  title_year  budget       Gross  \
# 0                  La La Land        2016    30.0  151.101803
# 1                    Zootopia        2016   150.0  341.268248
# 2                        Lion        2016    12.0   51.738905
# 3                     Arrival        2016    47.0  100.546139
# 4       Manchester by the Sea        2016     9.0   47.695371
# 5          Hell or High Water        2016    12.0   27.007844
# 6              Doctor Strange        2016   165.0  232.641920
# 7                     Tangled        2010   260.0  200.807262
# 8       The Dark Knight Rises        2012   250.0  448.130642
# 9  Captain America: Civil War        2016   250.0  407.197282
#
#            actor_1_name        actor_2_name          actor_3_name  \
# 0          Ryan Gosling          Emma Stone            Amiée Conn
# 1      Ginnifer Goodwin       Jason Bateman            Idris Elba
# 2             Dev Patel       Nicole Kidman           Rooney Mara
# ...

# %%
#Plot profit vs budget

# %%
sns.jointplot("profit","budget",data=movies)
plt.show()

# %%
#Find the movies with negative profit

# %%
movies[movies["profit"]<0]
# Out:
#                           Title  title_year  budget       Gross  \
# 7                       Tangled        2010   260.0  200.807262
# 17             Edge of Tomorrow        2014   178.0  100.189501
# 22                         Hugo        2011   170.0   73.820094
# 28           X-Men: First Class        2011   160.0  146.405371
# 39            The Little Prince        2015    81.2    1.339152
# 46  Scott Pilgrim vs. the World        2010    60.0   31.494270
# 56                         Rush        2013    38.0   26.903709
# 66                      Warrior        2011    25.0   13.651662
# 82                      Flipped        2010    14.0    1.752214
# 89                        Amour        2012     8.9    0.225377
# 99      Tucker and Dale vs Evil        2010     5.0    0.223838
#
#            actor_1_name        actor_2_name            actor_3_name  \
# 7          Brad Garrett        Donna Murphy             M.C. Gainey
# ...

# %%
# Change the scale of MetaCritic

# %%
movies["MetaCritic"]=movies["MetaCritic"]/10

# %%
movies
# Out:
#                                            Title  title_year  budget  \
# 0                                     La La Land        2016    30.0
# 1                                       Zootopia        2016   150.0
# 2                                           Lion        2016    12.0
# 3                                        Arrival        2016    47.0
# 4                          Manchester by the Sea        2016     9.0
# ..                                           ...         ...     ...
# 95                                      Whiplash        2014     3.3
# 96                               Before Midnight        2013     3.0
# 97    Star Wars: Episode VII - The Force Awakens        2015   245.0
# 98  Harry Potter and the Deathly Hallows: Part I        2010   150.0
# 99                       Tucker and Dale vs Evil        2010     5.0
#
#          Gross              actor_1_name        actor_2_name  \
# 0   151.101803              Ryan Gosling          Emma Stone
# ...

# %%
# Find the average ratings

# %%
movies["Average_rating"]=movies["MetaCritic"]+movies["IMDb_rating"]/2

# %%
movies
# Out:
#                                            Title  title_year  budget  \
# 0                                     La La Land        2016    30.0
# 1                                       Zootopia        2016   150.0
# 2                                           Lion        2016    12.0
# 3                                        Arrival        2016    47.0
# 4                          Manchester by the Sea        2016     9.0
# ..                                           ...         ...     ...
# 95                                      Whiplash        2014     3.3
# 96                               Before Midnight        2013     3.0
# 97    Star Wars: Episode VII - The Force Awakens        2015   245.0
# 98  Harry Potter and the Deathly Hallows: Part I        2010   150.0
# 99                       Tucker and Dale vs Evil        2010     5.0
#
#          Gross              actor_1_name        actor_2_name  \
# 0   151.101803              Ryan Gosling          Emma Stone
# ...

# %%
#Sort in descending order of average rating

# %%
movies[""]
